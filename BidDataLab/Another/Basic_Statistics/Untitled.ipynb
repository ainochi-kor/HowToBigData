# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# %matplotlib inline

# %%
input_file = 'encar_all_info_refine_01.csv'

# %%
#폰트설정
font_path="C:/Windows/Fonts/NanumGothic.ttf"
fontprop = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = 'Malgun Gothic'
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['DejaVu Sans Mono',
#  'cmr10',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmtt10',
#  'cmmi10',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'cmsy10',
#  'DejaVu Sans Display',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'cmex10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeFiveSym',
#  'STIXGeneral',
#  'Franklin Gothic Book',
#  'Monotype Corsiva',
#  'Book Antiqua',
#  'Dubai',
#  'Century Schoolbook',
#  'MingLiU-ExtB',
#  'Lucida Calligraphy',
#  'Impact',
#  'Showcard Gothic',
#  'Sitka Small',
#  'Harlow Solid Italic',
#  'Microsoft Yi Baiti',
#  'HYSinMyeongJo-Medium',
#  'MHunmin',
#  'Tw Cen MT',
#  'Edwardian Script ITC',
#  'Lucida Sans',
#  'Verdana',
#  'Ebrima',
#  'Wingdings 3',
#  'Cambria',
#  'Bodoni MT',
#  'Courier New',
#  'Lucida Sans Typewriter',
#  'HYPost-Light',
#  'Bradley Hand ITC',
#  'Rockwell Extra Bold',
#  'Palatino Linotype',
#  'Segoe MDL2 Assets',
#  'Arial',
#  'MDotum',
#  'Georgia',
#  'Cooper Black',
#  'Snap ITC',
#  'Trebuchet MS',
#  'Curlz MT',
#  'Leelawadee UI',
#  'Tempus Sans ITC',
#  'Wide Latin',
#  'Microsoft YaHei',
#  'Bodoni MT',
#  'Eras Light ITC',
#  'Sitka Small',
#  'MSugiJeong',
#  'Broadway',
#  'Times New Roman',
#  'Segoe Script',
#  'Lucida Handwriting',
#  'Magic R',
#  'Candara',
#  'Corbel',
#  'HYGraphic-Medium',
#  'HCR Dotum',
#  'KBIZgo R',
#  'Segoe UI Emoji',
#  'Comic Sans MS',
#  'Yu Gothic',
#  'HYGothic-Extra',
#  'Courier New',
#  'Garamond',
#  'Bodoni MT',
#  'MS Reference Specialty',
#  'Freestyle Script',
#  'Bodoni MT',
#  'Papyrus',
#  'Lucida Sans Unicode',
#  'High Tower Text',
#  'Lucida Bright',
#  'Cambria',
#  'Corbel',
#  'Onyx',
#  'HCR Dotum',
#  'Calibri',
#  'Century Gothic',
#  'Lucida Fax',
#  'HYPMokGak-Bold',
#  'Segoe UI',
#  'Matura MT Script Capitals',
#  'Lucida Fax',
#  'KBIZgo B',
#  'Berlin Sans FB',
#  'Franklin Gothic Demi',
#  'Tw Cen MT Condensed',
#  'Candara',
#  'Copperplate Gothic Light',
#  'Niagara Solid',
#  'Calibri',
#  'Consolas',
#  'Malgun Gothic',
#  'Palatino Linotype',
#  'Century',
#  'Bell MT',
#  'Segoe UI',
#  'Webdings',
#  'HYGungSo-Bold',
#  'Gabriola',
#  'Franklin Gothic Medium',
#  'Gulim',
#  'Bookman Old Style',
#  'Perpetua',
#  'MoeumT R',
#  'Arial',
#  'Goudy Old Style',
#  'Mistral',
#  'Microsoft Uighur',
#  'Century Gothic',
#  'Franklin Gothic Book',
#  'Arial',
#  'Wingdings 2',
#  'Bodoni MT',
#  'Calisto MT',
#  'Stencil',
#  'Chiller',
#  'Lucida Bright',
#  'Maiandra GD',
#  'Candara',
#  'Yu Gothic',
#  'HCR Batang',
#  'HoloLens MDL2 Assets',
#  'Constantia',
#  'HCR Batang',
#  'MV Boli',
#  'Dubai',
#  'HCR Batang ExtB',
#  'Franklin Gothic Demi Cond',
#  'Perpetua',
#  'Eras Bold ITC',
#  'Pyunji R',
#  'Corbel',
#  'Yu Gothic',
#  'Gadugi',
#  'Segoe UI Historic',
#  'Bodoni MT',
#  'Lucida Sans',
#  'Engravers MT',
#  'Britannic Bold',
#  'HYPost-Medium',
#  'Century Schoolbook',
#  'Gill Sans MT Condensed',
#  'Pristina',
#  'French Script MT',
#  'Imprint MT Shadow',
#  'Segoe UI',
#  'Arial',
#  'Jokerman',
#  'Malgun Gothic',
#  'Bernard MT Condensed',
#  'Georgia',
#  'Lucida Fax',
#  'Century Gothic',
#  'Times New Roman',
#  'Microsoft PhagsPa',
#  'Garamond',
#  'MGungHeulim',
#  'Californian FB',
#  'Segoe Script',
#  'Leelawadee UI',
#  'Segoe UI',
#  'Yu Gothic',
#  'High Tower Text',
#  'Niagara Engraved',
#  'Times New Roman',
#  'New Gulim',
#  'Palace Script MT',
#  'Trebuchet MS',
#  'KBIZmjo B',
#  'Consolas',
#  'Lucida Sans Typewriter',
#  'Bodoni MT',
#  'HYHeadLine-Medium',
#  'Ravie',
#  'Arial',
#  'Palatino Linotype',
#  'Felix Titling',
#  'Elephant',
#  'Arial',
#  'Calisto MT',
#  'Californian FB',
#  'Bodoni MT',
#  'Rockwell',
#  'Perpetua',
#  'Candara',
#  'Blackadder ITC',
#  'Myanmar Text',
#  'Microsoft YaHei',
#  'Times New Roman',
#  'Segoe UI',
#  'Verdana',
#  'Gill Sans Ultra Bold',
#  'MS Reference Sans Serif',
#  'Forte',
#  'Courier New',
#  'Segoe UI',
#  'Gloucester MT Extra Condensed',
#  'HCR Batang Ext',
#  'Gill Sans MT',
#  'Rockwell',
#  'Symbol',
#  'Constantia',
#  'KBIZgo M',
#  'Rage Italic',
#  'Castellar',
#  'Haettenschweiler',
#  'Baskerville Old Face',
#  'Microsoft Tai Le',
#  'HYGothic-Medium',
#  'Microsoft PhagsPa',
#  'Calibri',
#  'Lucida Bright',
#  'MS Gothic',
#  'Nirmala UI',
#  'Bookman Old Style',
#  'Garamond',
#  'Batang',
#  'Footlight MT Light',
#  'Vivaldi',
#  'MJemokGothic',
#  'Calibri',
#  'Perpetua',
#  'Agency FB',
#  'Corbel',
#  'Tahoma',
#  'Eras Demi ITC',
#  'Lucida Fax',
#  'Gill Sans MT',
#  'Leelawadee',
#  'Old English Text MT',
#  'Poor Richard',
#  'Tw Cen MT Condensed Extra Bold',
#  'Calisto MT',
#  'Trebuchet MS',
#  'Sitka Small',
#  'Corbel',
#  'SimSun',
#  'KBIZmjo M',
#  'Constantia',
#  'Calisto MT',
#  'Colonna MT',
#  'Lucida Sans Typewriter',
#  'Verdana',
#  'Bauhaus 93',
#  'Arial',
#  'Copperplate Gothic Bold',
#  'Consolas',
#  'Calibri',
#  'Dubai',
#  'Agency FB',
#  'Book Antiqua',
#  'Microsoft Tai Le',
#  'Book Antiqua',
#  'Leelawadee UI',
#  'Ami R',
#  'Tw Cen MT',
#  'Franklin Gothic Heavy',
#  'Consolas',
#  'Rockwell Condensed',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Kristen ITC',
#  'Corbel',
#  'Candara',
#  'Sitka Small',
#  'Microsoft Uighur',
#  'Viner Hand ITC',
#  'Gadugi',
#  'Microsoft New Tai Lue',
#  'Courier New',
#  'MBatang',
#  'Ink Free',
#  'HCR Dotum Ext',
#  'Gigi',
#  'Playbill',
#  'Gill Sans MT Ext Condensed Bold',
#  'Centaur',
#  'Bell MT',
#  'MT Extra',
#  'Comic Sans MS',
#  'Rockwell Condensed',
#  'Gill Sans MT',
#  'Lucida Sans Typewriter',
#  'Century Schoolbook',
#  'Bodoni MT',
#  'Palatino Linotype',
#  'Microsoft Himalaya',
#  'Yet R',
#  'Arial',
#  'Perpetua Titling MT',
#  'Californian FB',
#  'HYShortSamul-Medium',
#  'HCR Batang ExtB',
#  'Segoe UI',
#  'Brush Script MT',
#  'Perpetua Titling MT',
#  'Bookman Old Style',
#  'Eras Medium ITC',
#  'MSugiHeulim',
#  'Goudy Stout',
#  'Nirmala UI',
#  'Goudy Old Style',
#  'Franklin Gothic Heavy',
#  'Tw Cen MT',
#  'Century Gothic',
#  'NewJumja',
#  'Script MT Bold',
#  'Candara',
#  'Segoe Print',
#  'Comic Sans MS',
#  'Informal Roman',
#  'Microsoft YaHei',
#  'MGungJeong',
#  'Wingdings',
#  'MS Outlook',
#  'Segoe UI',
#  'Lucida Bright',
#  'Segoe Print',
#  'Franklin Gothic Medium Cond',
#  'Vladimir Script',
#  'Microsoft New Tai Lue',
#  'Arial',
#  'Headline R',
#  'Century Schoolbook',
#  'Georgia',
#  'Microsoft Sans Serif',
#  'Segoe UI',
#  'Ebrima',
#  'HYMyeongJo-Extra',
#  'Berlin Sans FB',
#  'Lucida Sans',
#  'Marlett',
#  'Segoe UI',
#  'Rockwell',
#  'Tw Cen MT',
#  'Modern No. 20',
#  'Tw Cen MT Condensed',
#  'Book Antiqua',
#  'Elephant',
#  'Comic Sans MS',
#  'Javanese Text',
#  'Mongolian Baiti',
#  'Juice ITC',
#  'Gill Sans Ultra Bold Condensed',
#  'Lucida Console',
#  'Berlin Sans FB Demi',
#  'Bahnschrift',
#  'KBIZmjo R',
#  'Leelawadee',
#  'Bookshelf Symbol 7',
#  'Segoe UI Symbol',
#  'Constantia',
#  'MJemokBatang',
#  'Algerian',
#  'Tahoma',
#  'Myanmar Text',
#  'Microsoft JhengHei',
#  'Georgia',
#  'Microsoft JhengHei',
#  'Bodoni MT',
#  'Trebuchet MS',
#  'Bodoni MT',
#  'Bookman Old Style',
#  'SimSun-ExtB',
#  'Rockwell',
#  'Malgun Gothic',
#  'Franklin Gothic Demi',
#  'Sylfaen',
#  'Lucida Sans',
#  'Harrington',
#  'Gill Sans MT',
#  'Verdana',
#  'Nirmala UI',
#  'Parchment',
#  'Arial Rounded MT Bold',
#  'Bell MT',
#  'Cambria',
#  'Dubai',
#  'HyhwpEQ',
#  'OCR A Extended',
#  'Goudy Old Style',
#  'Kunstler Script',
#  'Magneto',
#  'Segoe UI',
#  'Cambria',
#  'Franklin Gothic Medium',
#  'Calibri']

# %%
df = pd.read_csv(input_file)
print(df.describe())
# Out:
#           Unnamed: 0          money
# count  111580.000000  111580.000000
# mean    55836.520344    1857.216266
# std     32286.470843    2080.675383
# min         0.000000     210.000000
# 25%     27894.750000     700.000000
# 50%     55789.500000    1290.000000
# 75%     83684.250000    2480.000000
# max    112300.000000   46300.000000

# %%
#데이터셋 처음 5개 출력하기
print(df.head())
# Out:
#    Unnamed: 0 company                    engine engine2         km location  \
# 0           0      현대                   G330 모던     NaN   61,103km       광주
# 1           1      현대                   1.7 VGT     PYL  174,928km       대구
# 2           2      현대            HG300 프리미엄 컬렉션     NaN   60,845km       광주
# 3           3      현대               가솔린 3.8 4WD   프레스티지   21,281km       광주
# 4           4      현대  디젤(e-VGT) 2.0 2WD 익스클루시브     스페셜   49,417km       광주
#
#      model   money         year
# 0  제네시스 DH  2650.0      04월 16일
# 1   i40 살룬   780.0  13/07(14년식)
# 2   그랜저 HG  1750.0      07월 16일
# 3    팰리세이드  4650.0  18/12(19년식)
# 4   싼타페 DM  1990.0  14/03(15년식)

# %%
X = df["money"]
y = df["company"]
plt.plot(X,y,'o')
plt.show()
